# %% [markdown]
# k-means는 거리 기반 클러스터링 방법이었는데요. 이번 레슨부터는 다른 기준을 사용하는 모델들에 대해 살펴보겠습니다.
#
# 먼저, 거리 말고 어떤 게 클러스터링의 기준으로 사용될 수 있는지부터 간단히 알아볼게요.

# %% [markdown]
# ## 계층 기반 클러스터링
# 계층 구조를 바탕으로 클러스터링을 진행하는 방법입니다.
# 기본적으로 유사한 데이터를 묶은 클러스터들을 층으로 쌓아가며 클러스터링하는 방식인데요.
# 시각화된 결과물을 통해 데이터 간 관계를 쉽게 파악할 수 있고, 원하는 수의 클러스터로 간단하게 구분이 가능합니다.

# %% [markdown]
# ## 밀도 기반 클러스터링
# 밀도가 높은 부분을 같은 클러스터로 묶어 나가는 방식입니다. 어떤 데이터가 클러스터에 속할 경우 클러스터 내에 다른 많은 데이터와
# 가까운 위치에 있을 것이라는 아이디어에서 출발합니다.
# 밀도 기반 클러스터링은 기하학적인 형태의 데이터를 클러스터링할 때 효과적입니다.

# %% [markdown]
# ## 분포 기반 클러스터링
# 각 클러스터에 포함된 데이터들이 정규분포를 따른다고 가정했을 때, 특정 데이터가 포함될 확률이 가장 높은 분포의 클러스터가
# 무엇인지를 찾아 클러스터를 나누는 방법입니다.
